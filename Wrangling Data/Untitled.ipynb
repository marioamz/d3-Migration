# %%
import pandas as pd

# %%
vio = pd.read_csv('d3data/violence.csv')

# %%
vio
# Out:
#     Unnamed: 0  Unnamed: 0.1  Index                            State  \
# 0            0             0      1                   Aguascalientes
# 1            1             1      2                  Baja California
# 2            2             2      3              Baja California Sur
# 3            3             3      4                         Campeche
# 4            4             4      5                          Chiapas
# 5            5             5      6                        Chihuahua
# 6            6             6      7             Coahuila de Zaragoza
# 7            7             7      8                           Colima
# 8            8             8      9                 Distrito Federal
# 9            9             9     10                          Durango
# 10          10            10     11                       Guanajuato
# 11          11            11     12                         Guerrero
# 12          12            12     13                          Hidalgo
# ...

# %%
vio['Index'] = vio['Index'].astype(str)

# %%
vio['Index'] = vio['Index'].replace(['1', '2', '3', '4', '5', '6', '7', '8', '9'], ['01', '02', '03', '04', '05', '06', '07', '08', '09'])

# %%
vio
# Out:
#     Unnamed: 0  Unnamed: 0.1 Index                            State  \
# 0            0             0    01                   Aguascalientes
# 1            1             1    02                  Baja California
# 2            2             2    03              Baja California Sur
# 3            3             3    04                         Campeche
# 4            4             4    05                          Chiapas
# 5            5             5    06                        Chihuahua
# 6            6             6    07             Coahuila de Zaragoza
# 7            7             7    08                           Colima
# 8            8             8    09                 Distrito Federal
# 9            9             9    10                          Durango
# 10          10            10    11                       Guanajuato
# 11          11            11    12                         Guerrero
# 12          12            12    13                          Hidalgo
# ...

# %%
vio.to_csv('d3data/violence.csv')
